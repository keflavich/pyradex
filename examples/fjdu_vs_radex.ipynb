# %%
# %matplotlib inline
import pylab as pl
pl.rcParams['figure.dpi'] = 150
pl.rcParams['savefig.dpi'] = 150
pl.rcParams['figure.figsize'] = (12,10)

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# %run fjdu_vs_radex.py
